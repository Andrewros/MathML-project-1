# %%
#import required modules
from matplotlib import pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
#Generate data for training and testing
np.random.seed(1)
def generate_data(std=1.0):
    x=np.random.uniform(0,10, 100)
    x=np.sort(x)
    y=3*x
    y+=np.random.normal(0, std, 100)
    x=x.reshape(100, 1)
    return x,y
x,y=generate_data()
xtrain, xtest, ytrain, ytest=train_test_split(x,y, test_size=0.2)

# %%
#Training the model and evaluating mean-squared error
model=LinearRegression()
model.fit(xtrain, ytrain)
mse=mean_squared_error(model.predict(xtest), ytest)

# %%
#Plotting the data and the regression line
plt.scatter(x,y)
plt.plot(x, model.predict(x), color="red", linewidth=2)
plt.title("Linear Regression for std=1")
print(f"Mean squared error: {mse}")
plt.show()
# Out:
# Mean squared error: 0.7530907468722747

# %%
#Repeat for sigma=0.1
np.random.seed(1)
x,y=generate_data(std=0.1)
xtrain, xtest, ytrain, ytest=train_test_split(x,y, test_size=0.2)
model=LinearRegression()
model.fit(xtrain, ytrain)
mse=mean_squared_error(model.predict(xtest), ytest)
print(f"Mean squared error: {mse}")
#Plotting the data and the regression line
plt.scatter(x,y)
plt.title("Linear Regression for std=0.1")
plt.plot(x, model.predict(x), color="red", linewidth=2)
plt.show()
# Out:
# Mean squared error: 0.0075309074687225554

# %%
#Repeat for sigma=0.5
np.random.seed(1)
x,y=generate_data(std=0.5)
xtrain, xtest, ytrain, ytest=train_test_split(x,y, test_size=0.2)
model=LinearRegression()
model.fit(xtrain, ytrain)
mse=mean_squared_error(model.predict(xtest), ytest)
print(f"Mean squared error: {mse}")
#Plotting the data and the regression line
plt.scatter(x,y)
plt.title("Linear Regression for std=0.5")
plt.plot(x, model.predict(x), color="red", linewidth=2)
plt.show()
# Out:
# Mean squared error: 0.18827268671806946

# %%
#Repeat for sigma=2
np.random.seed(1)
x,y=generate_data(std=2)
xtrain, xtest, ytrain, ytest=train_test_split(x,y, test_size=0.2)
model=LinearRegression()
model.fit(xtrain, ytrain)
mse=mean_squared_error(model.predict(xtest), ytest)
print(f"Mean squared error: {mse}")
#Plotting the data and the regression line
plt.scatter(x,y)
plt.title("Linear Regression for std=2")
plt.plot(x, model.predict(x), color="red", linewidth=2)
plt.show()
# Out:
# Mean squared error: 3.012362987489099
